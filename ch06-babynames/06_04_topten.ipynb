# %% [markdown]
# # 06_04: A yearly top ten

# %%
import math
import collections
import dataclasses
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %%
allyears = pd.read_feather('allyears.feather')

# %%
allyears_byyear = allyears.set_index(['sex', 'year']).sort_index()

# %%
allyears_byyear.loc['M', 2000].sort_values('number', ascending=False)
# Out:
#                  name  number
# sex year
# M   2000        Jacob   34490
#     2000      Michael   32042
#     2000      Matthew   28579
#     2000       Joshua   27540
#     2000  Christopher   24936
# ...               ...     ...
#     2000         Zeph       5
#     2000        Zeven       5
#     2000        Ziggy       5
#     2000           Zo       5
#     2000        Zyier       5
#
# [12118 rows x 2 columns]

# %%
allyears_byyear.loc['M', 2023].sort_values('number', ascending=False).head(10)
# Out:
#               name  number
# sex year
# M   2023      Liam   20802
#     2023      Noah   18995
#     2023    Oliver   14741
#     2023     James   11670
#     2023    Elijah   11452
#     2023     Mateo   11229
#     2023  Theodore   11041
#     2023     Henry   10941
#     2023     Lucas   10842
#     2023   William   10598

# %%
allyears_byyear.loc['F', 2023].sort_values('number', ascending=False).head(10)
# Out:
#                name  number
# sex year
# F   2023     Olivia   15270
#     2023       Emma   13527
#     2023  Charlotte   12596
#     2023     Amelia   12311
#     2023     Sophia   11944
#     2023        Mia   11359
#     2023   Isabella   10808
#     2023        Ava    9682
#     2023     Evelyn    9082
#     2023       Luna    7811

# %%
allyears_byyear.loc['F', 2023].sort_values('number', ascending=False).head(10).reset_index().name
# Out:
# 0       Olivia
# 1         Emma
# 2    Charlotte
# 3       Amelia
# 4       Sophia
# 5          Mia
# 6     Isabella
# 7          Ava
# 8       Evelyn
# 9         Luna
# Name: name, dtype: string

# %%
def getyear(sex, year):
    return (allyears_byyear.loc[sex, year].sort_values('number', ascending=False).head(10).reset_index().name)

# %%
pd.DataFrame({year: getyear('M', year) for year in range(2014, 2024)})
# Out:
#         2014       2015      2016      2017      2018       2019       2020  \
# 0       Noah       Noah      Noah      Liam      Liam       Liam       Liam
# 1       Liam       Liam      Liam      Noah      Noah       Noah       Noah
# 2      Mason      Mason   William   William   William     Oliver     Oliver
# 3      Jacob      Jacob     Mason     James     James    William     Elijah
# 4    William    William     James     Logan    Oliver     Elijah    William
# 5      Ethan      Ethan  Benjamin  Benjamin  Benjamin      James      James
# 6    Michael      James     Jacob     Mason    Elijah   Benjamin   Benjamin
# 7  Alexander  Alexander   Michael    Elijah     Lucas      Lucas      Lucas
# 8      James    Michael    Elijah     Jacob     Mason      Mason      Henry
# 9     Daniel   Benjamin     Ethan    Oliver     Logan  Alexander  Alexander
#
#        2021      2022      2023
# 0      Liam      Liam      Liam
# 1      Noah      Noah      Noah
# 2    Oliver    Oliver    Oliver
# 3    Elijah     James     James
# 4     James    Elijah    Elijah
# 5   William   William     Mateo
# 6  Benjamin     Henry  Theodore
# 7     Lucas     Lucas     Henry
# 8     Henry  Benjamin     Lucas
# 9  Theodore  Theodore   William

# %%
pd.DataFrame({year: getyear('F', year) for year in range(2014, 2024)})
# Out:
#         2014       2015       2016       2017       2018       2019  \
# 0       Emma       Emma       Emma       Emma       Emma     Olivia
# 1     Olivia     Olivia     Olivia     Olivia     Olivia       Emma
# 2     Sophia     Sophia        Ava        Ava        Ava        Ava
# 3   Isabella        Ava     Sophia   Isabella   Isabella     Sophia
# 4        Ava   Isabella   Isabella     Sophia     Sophia   Isabella
# 5        Mia        Mia        Mia        Mia  Charlotte  Charlotte
# 6      Emily    Abigail  Charlotte  Charlotte        Mia     Amelia
# 7    Abigail      Emily    Abigail     Amelia     Amelia        Mia
# 8    Madison  Charlotte      Emily     Evelyn     Harper     Harper
# 9  Charlotte     Harper     Amelia    Abigail     Evelyn     Evelyn
#
#         2020       2021       2022       2023
# 0     Olivia     Olivia     Olivia     Olivia
# 1       Emma       Emma       Emma       Emma
# 2        Ava  Charlotte  Charlotte  Charlotte
# 3  Charlotte     Amelia     Amelia     Amelia
# 4     Sophia        Ava     Sophia     Sophia
# 5     Amelia     Sophia   Isabella        Mia
# 6   Isabella   Isabella        Ava   Isabella
# 7        Mia        Mia        Mia        Ava
# 8     Evelyn     Evelyn     Evelyn     Evelyn
# 9     Harper     Harper       Luna       Luna

# %%
allyears_byname = allyears.set_index(['sex', 'name', 'year']).sort_index()

# %%
pp.figure(figsize=(9,2))

for name in getyear('F', 2023):
    pp.plot(allyears_byname.loc['F', name], label=name)

pp.axis(xmin=1880, xmax=2024)
pp.legend(loc='upper left', fontsize=8);

# %%
pp.figure(figsize=(9,2))

for name in getyear('M', 2023):
    pp.plot(allyears_byname.loc['M', name], label=name)

pp.axis(xmin=1880, xmax=2024)
pp.legend(loc='upper left', fontsize=8);

# %%
alltime_f = allyears_byyear.loc['F'] \
                            .groupby('name') \
                            .sum() \
                            .sort_values('number', ascending=False) \
                            .head(10)

# %%
alltime_f
# Out:
#             number
# name
# Mary       4136872
# Elizabeth  1674865
# Patricia   1573241
# Jennifer   1470608
# Linda      1454476
# Barbara    1436052
# Margaret   1259974
# Susan      1122984
# Dorothy    1110746
# Sarah      1092927

# %%
allyears_byname.loc[pd.IndexSlice['F', getyear('F', 2023), :]].groupby('name').sum()
# Out:
#            number
# name
# Amelia     255502
# Ava        327483
# Charlotte  427311
# Emma       749903
# Evelyn     621387
# Isabella   395255
# Luna        74374
# Mia        286817
# Olivia     538805
# Sophia     414202

# %%
pp.figure(figsize=(9,2))

for name in alltime_f.index:
    pp.plot(allyears_byname.loc['M', name], label=name)

pp.axis(xmin=1880, xmax=2024)
pp.legend(loc='upper left', fontsize=8);
